# %% [markdown]
# Com o modelo já treinado, utiliza-se essa matriz para buscar as similaridades com os textos das buscas, cujos textos também passarão por uma etapa de preprocessamento.

# %%
import numpy as np
import pandas as pd
import pickle
import gensim
import spacy
from gensim.similarities.docsim import MatrixSimilarity
from nltk.corpus import stopwords
from gensim import corpora

nlp = spacy.load('pt_core_news_lg')

# * adding custom texts that dont represent real words
noises_list = ["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x", "xi"]

stopWords_list = stopwords.words("portuguese")

# * adding custom words to StopWords list
stopWords_list += [
    'referente',
    'seguinte'
]

# * preprocessing stopwords to correct format
stopWords_list = gensim.utils.simple_preprocess(" ".join(stopWords_list), deacc=True, min_len=1, max_len=40)

# * manual intervention, changing final lemmas
intervention_dict = {
    "campar": "campo",
    "seriar":"serie",
    "eletromagnetico":"eletromagnetismo",
}

def preprocess(text):
    # * importing stopwords from nltk and spacy pipeline
    global nlp
    global stopWords_list
    global noises_list
    global intervention_dict

    # * preprocessing text with gensim.simple_preprocess, eliminating noises: lowercase, tokenized, no symbols, no numbers, no accents marks(normatize)
    text_list = gensim.utils.simple_preprocess(text, deacc=True, min_len=1, max_len=40)

    # * recombining tokens to a string type object and removing remaining noises
    text_str = " ".join([word for word in text_list if word not in noises_list])

    # * preprocessing with spacy, retokenizing -> tagging parts of speech (PoS) -> parsing (assigning dependencies between words) -> lemmatizing
    text_doc = nlp(text_str)

    # * re-tokenization, removing stopwords and lemmatizing
    lemmatized_text_list = [token.lemma_ for token in text_doc if token.text not in stopWords_list]

    # * manual intervention conversion of lemmas
    output = []
    for token in lemmatized_text_list:
        if token in intervention_dict:
            output.append(intervention_dict[token])
        else:
            output.append(token)
            
    return output

tfidf_corpus = gensim.corpora.MmCorpus('tfidf_model_mm')
lsi_corpus = gensim.corpora.MmCorpus('lsi_model_mm')

with open('id2wordDict.txt', 'rb') as f:
    id2wordDict = pickle.load(f)

with open("tfidf_model.txt", 'rb') as f:
    tfidf_model = pickle.load(f)

with open("lsi_model.txt", 'rb') as f:
    lsi_model = pickle.load(f)

with open('crea_df_pickle.txt', 'rb') as f:
    crea_df = pickle.load(f)

subjects_df = pd.read_json("MechatronicsEngeneeringSubjects.json")

# * seção de Construção de Edificações
subsection1_df = crea_df[ crea_df['SUB-SETOR'] == 'Construção de Edificações']

cosineSimilarity = MatrixSimilarity(lsi_corpus, num_features = lsi_corpus.num_terms, num_best=8)

def search_similarity_query(search_document):

    # * preprocessing and processing until becomes a matrix of type term_to_topic (V)
    doc = preprocess(search_document)
    query_bow = id2wordDict.doc2bow(doc)
    query_tfidf = tfidf_model[query_bow]
    query_lsi = lsi_model[query_tfidf]

    # * cossine similarity between the vector of the new document vs all other vectors of documents
    # * returns a list of tuples (id of compared document, similarity)
    ranking = cosineSimilarity[query_lsi]

    ranking.sort(key=lambda unit: unit[1], reverse= True)
    result = []

    for subject in ranking:

        result.append (
            {
                'Relevancia': round((subject[1] * 100),6),
                'Código da Matéria': subjects_df['codigo'][subject[0]],
                'Nome da matéria': subjects_df['nome'][subject[0]]
            }

        )
    
    output = pd.DataFrame(result, columns=['Relevancia','Código da Matéria','Nome da matéria'])
    if len(output) == 0:
        return "O texto procurado não há similaridade com nenhuma das demais"
    return output
# Out:
# ['serie']

# %% [markdown]
# # Single Queries

# %%
print("preprocessed:", preprocess("series"))
search_similarity_query("series")
# Out:
# ['serie']
#    Relevancia Código da Matéria                       Nome da matéria
# 0   77.580750           MAT0059       METODOS MATEMÁTICOS DA FÍSICA 1
# 1   61.287850           MAT0026                             CÁLCULO 2
# 2   43.210536           MAT0028                   VARIAVEL COMPLEXA 1
# 3   27.108598           ENE0038  LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4   24.388134           ENE0037                 CIRCUITOS ELÉTRICOS 2
# 5   12.979302           IFD0181                FISICA 3 EXPERIMENTAL
# 6    8.841469           ENE0047   CONVERSÃO ELETROMECÂNICA DE ENERGIA
# 7    7.871081           ENE0042                 CIRCUITOS ELÉTRICOS 1

# %% [markdown]
# # Multi Queries

# %%
subsection1_df.head(15)

for i in range(15):
    text = subsection1_df.iloc[i, 8]
    print(f'texto buscado: {text}')
    print(f'texto buscado preprocessado: {preprocess(text)}')
    print( search_similarity_query(text), end='\n\n')
# Out:
# texto buscado: Cálculo diferencial e integral
# texto buscado preprocessado: ['calcular', 'diferencial', 'integral']
#    Relevancia Código da Matéria        Nome da matéria
# 0   94.680548           MAT0025              CÁLCULO 1
# 1   29.648611           MAT0027              CÁLCULO 3
# 2   29.401502           MAT0028    VARIAVEL COMPLEXA 1
# 3   21.390662           ENE0045             ELETRÔNICA
# 4   15.841775           MAT0026              CÁLCULO 2
# 5   13.828565           ENE0037  CIRCUITOS ELÉTRICOS 2
# 6    9.978841           IFD0179               FISICA 3
# 7    9.956482           IFD0177  FISICA 2 EXPERIMENTAL
#
# texto buscado: Cálculo numérico
# texto buscado preprocessado: ['calcular', 'numerico']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   83.769476           ENM0027  TECNOLOGIAS DE COMANDO NUMERICO
# 1   38.392425           MAT0053                 CALCULO NUMERICO
# 2   23.952121           MAT0027                        CÁLCULO 3
# 3   20.602839           MAT0025                        CÁLCULO 1
# 4   12.017112           IFD0179                         FISICA 3
# 5   11.990181           IFD0177            FISICA 2 EXPERIMENTAL
# 6   10.495166           IFD0173            FISICA 1 EXPERIMENTAL
# 7    7.322562           EST0023      PROBABILIDADE E ESTATÍSTICA
#
# texto buscado: Álgebra linear
# texto buscado preprocessado: ['algebra', 'linear']
#    Relevancia Código da Matéria                   Nome da matéria
# 0   65.031183           MAT0031       INTRODUCAO A ALGEBRA LINEAR
# 1   43.844181           CIC0229                 CIRCUITOS LÓGICOS
# 2   33.207384           MAT0028               VARIAVEL COMPLEXA 1
# 3   28.629756           MAT0026                         CÁLCULO 2
# 4   25.113592           IFD0173             FISICA 1 EXPERIMENTAL
# 5   24.377556           IFD0171                          FISICA 1
# 6   23.173559           ENM0120                        MECANICA 1
# 7   20.335254           CIC0231  LABORATÓRIO DE CIRCUITOS LÓGICOS
#
# texto buscado: Equações diferenciais
# texto buscado preprocessado: ['equacoes', 'diferenciar']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   95.553553           MAT0026                        CÁLCULO 2
# 1   40.736300           MAT0053                 CALCULO NUMERICO
# 2    7.355384           ENM0121                       MECANICA 2
# 3    6.679592           MAT0059  METODOS MATEMÁTICOS DA FÍSICA 1
# 4    4.580209           IFD0179                         FISICA 3
# 5    4.569946           IFD0177            FISICA 2 EXPERIMENTAL
# 6    2.480241           MAT0028              VARIAVEL COMPLEXA 1
# 7    1.941448           IFD0171                         FISICA 1
#
# texto buscado: Geometria Analítica
# texto buscado preprocessado: ['geometria', 'analitica']
#    Relevancia Código da Matéria                              Nome da matéria
# 0   88.250768           ENM0131  DESENHO MECANICO ASSISTIDO POR COMPUTADOR 1
# 1   47.702348           ENM0127                   TECNOLOGIA DE FABRICACAO 1
# 2    0.000001           EST0023                  PROBABILIDADE E ESTATÍSTICA
# 3    0.000001           ENM0027              TECNOLOGIAS DE COMANDO NUMERICO
# 4   -0.000001           ENM0118                          SISTEMAS DE MEDIÇÃO
# 5   -0.000001           ENM0133          INTRODUCAO A ENGENHARIA MECATRONICA
# 6   -0.000001           IFD0179                                     FISICA 3
# 7   -0.000004           ENM0116                   TECNOLOGIA DE FABRICACAO 2
#
# texto buscado: Séries
# texto buscado preprocessado: ['serie']
#    Relevancia Código da Matéria                       Nome da matéria
# 0   77.580750           MAT0059       METODOS MATEMÁTICOS DA FÍSICA 1
# 1   61.287850           MAT0026                             CÁLCULO 2
# 2   43.210536           MAT0028                   VARIAVEL COMPLEXA 1
# 3   27.108598           ENE0038  LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4   24.388134           ENE0037                 CIRCUITOS ELÉTRICOS 2
# 5   12.979302           IFD0181                FISICA 3 EXPERIMENTAL
# 6    8.841469           ENE0047   CONVERSÃO ELETROMECÂNICA DE ENERGIA
# 7    7.871081           ENE0042                 CIRCUITOS ELÉTRICOS 1
#
# texto buscado: Medidas físicas
# texto buscado preprocessado: ['medir', 'fisicas']
#    Relevancia Código da Matéria              Nome da matéria
# 0   69.935888           IFD0171                     FISICA 1
# 1   35.924873           IFD0177        FISICA 2 EXPERIMENTAL
# 2   32.909691           EST0023  PROBABILIDADE E ESTATÍSTICA
# 3   31.445509           IFD0173        FISICA 1 EXPERIMENTAL
# 4   30.163932           IQD0125        QUIMICA GERAL TEORICA
# 5   24.402192           IFD0181       FISICA 3 EXPERIMENTAL
# 6   11.443691           ENM0127   TECNOLOGIA DE FABRICACAO 1
# 7   11.424101           IQD0126   QUIMICA GERAL EXPERIMENTAL
#
# texto buscado: Mecânica
# texto buscado preprocessado: ['mecanica']
#    Relevancia Código da Matéria                              Nome da matéria
# 0   65.372568           ENM0120                                   MECANICA 1
# 1   58.909261           ENM0116                   TECNOLOGIA DE FABRICACAO 2
# 2   48.125443           IFD0171                                     FISICA 1
# 3   40.517426           ENM0121                                   MECANICA 2
# 4   21.926048           IFD0175                                     FISICA 2
# 5   20.750341           ENM0128                  TRANSPORTE DE CALOR E MASSA
# 6   17.697890           ENM0164                     MECANICA DOS MATERIAIS 1
# 7   14.835325           ENM0131  DESENHO MECANICO ASSISTIDO POR COMPUTADOR 1
#
# texto buscado: Eletromagnetismo
# texto buscado preprocessado: ['eletromagnetismo']
#    Relevancia Código da Matéria  \
# 0   92.898870           IFD0181
# 1    0.000003           IFD0179
# 2   -0.000001           IFD0177
# 3   -0.000001           ENM0027
# 4   -0.000001           ENM0128
# 5   -0.000001           MAT0027
# 6   -0.000002           ENE0046
# 7   -0.000003           ENE0048
#
#                                      Nome da matéria
# 0                             FISICA 3 EXPERIMENTAL
# 1                                           FISICA 3
# 2                              FISICA 2 EXPERIMENTAL
# 3                    TECNOLOGIAS DE COMANDO NUMERICO
# 4                        TRANSPORTE DE CALOR E MASSA
# 5                                          CÁLCULO 3
# 6                          LABORATÓRIO DE ELETRÔNICA
# 7  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
#
# texto buscado: Gravitação
# texto buscado preprocessado: ['gravitacao']
#    Relevancia Código da Matéria  \
# 0   86.391646           IFD0175
# 1    0.000001           IFD0177
# 2    0.000001           CIC0099
# 3    0.000001           IQD0125
# 4    0.000001           ENM0131
# 5   -0.000001           MAT0027
# 6   -0.000001           ENE0048
# 7   -0.000001           IFD0173
#
#                                      Nome da matéria
# 0                                           FISICA 2
# 1                              FISICA 2 EXPERIMENTAL
# 2          ORGANIZAÇÃO E ARQUITETURA DE COMPUTADORES
# 3                              QUIMICA GERAL TEORICA
# 4        DESENHO MECANICO ASSISTIDO POR COMPUTADOR 1
# 5                                          CÁLCULO 3
# 6  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
# 7                              FISICA 1 EXPERIMENTAL
#
# texto buscado: Termodinâmica
# texto buscado preprocessado: ['termodinamica']
#    Relevancia Código da Matéria                       Nome da matéria
# 0   82.876801           IFD0175                              FISICA 2
# 1   58.824623           ENM0128           TRANSPORTE DE CALOR E MASSA
# 2   26.152551           IQD0125                 QUIMICA GERAL TEORICA
# 3    0.000001           ENE0038  LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4    0.000001           IFD0171                              FISICA 1
# 5    0.000001           ENM0120                            MECANICA 1
# 6    0.000001           ENE0037                 CIRCUITOS ELÉTRICOS 2
# 7   -0.000001           ENM0164              MECANICA DOS MATERIAIS 1
#
# texto buscado: Ótica
# texto buscado preprocessado: ['otica']
# O texto procurado não há similaridade com nenhuma das demais
#
# texto buscado: Relatividade e física quântica
# texto buscado preprocessado: ['relatividade', 'fisica', 'quantica']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   66.502696           IFD0171                         FISICA 1
# 1   45.818466           IQD0125            QUIMICA GERAL TEORICA
# 2   31.511512           IFD0177            FISICA 2 EXPERIMENTAL
# 3   30.705541           MAT0059  METODOS MATEMÁTICOS DA FÍSICA 1
# 4   27.582443           IFD0173            FISICA 1 EXPERIMENTAL
# 5   18.184647           ENM0120                       MECANICA 1
# 6   15.791145           IFD0179                         FISICA 3
# 7    9.379722           ENE0077   CONTROLE DE SISTEMAS DINÂMICOS
#
# texto buscado: Atividades de laboratório
# texto buscado preprocessado: ['atividades', 'laboratorio']
#    Relevancia Código da Matéria  \
# 0   59.767115           ENE0048
# 1   57.452583           ENM0133
# 2   29.021764           ENM0127
# 3   23.416913           ENE0038
# 4   21.214911           ENE0044
# 5   20.156461           ENM0128
# 6    6.255810           ENE0046
# 7    6.095313           CIC0231
#
#                                      Nome da matéria
# 0  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
# 1                INTRODUCAO A ENGENHARIA MECATRONICA
# 2                         TECNOLOGIA DE FABRICACAO 1
# 3               LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4               LABORATÓRIO DE CIRCUITOS ELÉTRICOS 1
# 5                        TRANSPORTE DE CALOR E MASSA
# 6                          LABORATÓRIO DE ELETRÔNICA
# 7                   LABORATÓRIO DE CIRCUITOS LÓGICOS
#
# texto buscado: Estrutura atômica
# texto buscado preprocessado: ['estruturar', 'atomica']
#    Relevancia Código da Matéria                           Nome da matéria
# 0   67.034924           IQD0125                     QUIMICA GERAL TEORICA
# 1   45.195213           CIC0004  ALGORITMOS E PROGRAMAÇÃO DE COMPUTADORES
# 2   35.516769           CIC0090                       ESTRUTURAS DE DADOS
# 3   28.982049           ENM0120                                MECANICA 1
# 4   26.434767           ENM0133       INTRODUCAO A ENGENHARIA MECATRONICA
# 5   23.991799           CIC0229                         CIRCUITOS LÓGICOS
# 6   22.092000           ENM0126        INTRODUÇÃO À CIÊNCIA DOS MATERIAIS
# 7   11.127572           CIC0231          LABORATÓRIO DE CIRCUITOS LÓGICOS
