# %% [markdown]
# Com o modelo já treinado, utiliza-se essa matriz para buscar as similaridades com os textos das buscas, cujos textos também passarão por uma etapa de preprocessamento.

# %%
import numpy as np
import pandas as pd
import pickle
import gensim
import spacy
from gensim.similarities.docsim import MatrixSimilarity
from nltk.corpus import stopwords
from gensim import corpora

nlp = spacy.load('pt_core_news_lg')

# * adding custom texts that dont represent real words
noises_list = ["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x", "xi"]

stopWords_list = stopwords.words("portuguese")

# * adding custom words to StopWords list
stopWords_list += [
    'referente',
    'seguinte',
    'etc',
    'ª',
    'tal',
    'um', 
    'dois',
    'tres',
    'vs',
    'aula',
    'tal',
]

# * preprocessing stopwords to correct format
stopWords_list = gensim.utils.simple_preprocess(" ".join(stopWords_list), deacc=True, min_len=1, max_len=40)

# * manual intervention, changing final lemmas
intervention_dict = {
    "campar": "campo",
    "seriar":"serie",
    "eletromagnetico":"eletromagnetismo",
}

def preprocess(text):
    # * importing stopwords from nltk and spacy pipeline
    global nlp
    global stopWords_list
    global noises_list
    global intervention_dict

    # * preprocessing text with gensim.simple_preprocess, eliminating noises: lowercase, tokenized, no symbols, no numbers, no accents marks(normatize)
    text_list = gensim.utils.simple_preprocess(text, deacc=True, min_len=1, max_len=40)

    # * recombining tokens to a string type object and removing remaining noises
    text_str = " ".join([word for word in text_list if word not in noises_list])

    # * preprocessing with spacy, retokenizing -> tagging parts of speech (PoS) -> parsing (assigning dependencies between words) -> lemmatizing
    text_doc = nlp(text_str)

    # * re-tokenization, removing stopwords and lemmatizing
    lemmatized_text_list = [token.lemma_ for token in text_doc if token.text not in stopWords_list]

    # * manual intervention conversion of lemmas
    output = []
    for token in lemmatized_text_list:
        if token in intervention_dict:
            output.append(intervention_dict[token])
        else:
            output.append(token)
            
    return output

tfidf_corpus = gensim.corpora.MmCorpus('tfidf_model_mm')
lsi_corpus = gensim.corpora.MmCorpus('lsi_model_mm')

with open('id2wordDict.txt', 'rb') as f:
    id2wordDict = pickle.load(f)

with open("tfidf_model.txt", 'rb') as f:
    tfidf_model = pickle.load(f)

with open("lsi_model.txt", 'rb') as f:
    lsi_model = pickle.load(f)

with open('crea_df_pickle.txt', 'rb') as f:
    crea_df = pickle.load(f)

subjects_df = pd.read_json("MechatronicsEngeneeringSubjects.json")

# * seção de Construção de Edificações
subsection1_df = crea_df[ crea_df['SUB-SETOR'] == 'Construção de Edificações']

cosineSimilarity = MatrixSimilarity(lsi_corpus, num_features = lsi_corpus.num_terms, num_best=8)

def search_similarity_query(search_document):

    # * preprocessing and processing until becomes a matrix of type term_to_topic (V)
    doc = preprocess(search_document)
    query_bow = id2wordDict.doc2bow(doc)
    query_tfidf = tfidf_model[query_bow]
    query_lsi = lsi_model[query_tfidf]

    # * cossine similarity between the vector of the new document vs all other vectors of documents
    # * returns a list of tuples (id of compared document, similarity)
    ranking = cosineSimilarity[query_lsi]

    ranking.sort(key=lambda unit: unit[1], reverse= True)
    result = []

    for subject in ranking:

        result.append (
            {
                'Relevancia': round((subject[1] * 100),6),
                'Código da Matéria': subjects_df['codigo'][subject[0]],
                'Nome da matéria': subjects_df['nome'][subject[0]]
            }

        )
    
    output = pd.DataFrame(result, columns=['Relevancia','Código da Matéria','Nome da matéria'])
    if len(output) == 0:
        return "O texto procurado não há similaridade com nenhuma das demais"
    return output
# Out:
# D:\ANACONDA\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # Single Queries

# %%
print("preprocessed:", preprocess("series"))
search_similarity_query("series")
# Out:
# preprocessed: ['serie']
#    Relevancia Código da Matéria                       Nome da matéria
# 0   76.564622           MAT0059       METODOS MATEMÁTICOS DA FÍSICA 1
# 1   63.985479           MAT0026                             CÁLCULO 2
# 2   43.135533           MAT0028                   VARIAVEL COMPLEXA 1
# 3   27.754259           ENE0038  LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4   25.122958           ENE0037                 CIRCUITOS ELÉTRICOS 2
# 5   13.211061           IFD0181                FISICA 3 EXPERIMENTAL
# 6    9.392942           ENE0047   CONVERSÃO ELETROMECÂNICA DE ENERGIA
# 7    7.837956           ENE0042                 CIRCUITOS ELÉTRICOS 1

# %% [markdown]
# # Multi Queries

# %%
subsection1_df.head(15)

for i in range(15):
    text = subsection1_df.iloc[i, 8]
    print(f'texto buscado: {text}')
    print(f'texto buscado preprocessado: {preprocess(text)}')
    print( search_similarity_query(text), end='\n\n')
# Out:
# texto buscado: Cálculo diferencial e integral
# texto buscado preprocessado: ['calcular', 'diferencial', 'integral']
#    Relevancia Código da Matéria        Nome da matéria
# 0   92.505252           MAT0025              CÁLCULO 1
# 1   33.306983           MAT0027              CÁLCULO 3
# 2   27.137831           MAT0028    VARIAVEL COMPLEXA 1
# 3   22.743544           ENE0045             ELETRÔNICA
# 4   16.101868           MAT0026              CÁLCULO 2
# 5   13.171327           ENE0037  CIRCUITOS ELÉTRICOS 2
# 6   11.886820           CIC0104        SOFTWARE BASICO
# 7   11.025842           IFD0177  FISICA 2 EXPERIMENTAL
#
# texto buscado: Cálculo numérico
# texto buscado preprocessado: ['calcular', 'numerico']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   83.438993           ENM0027  TECNOLOGIAS DE COMANDO NUMERICO
# 1   36.913490           MAT0053                 CALCULO NUMERICO
# 2   23.679298           MAT0027                        CÁLCULO 3
# 3   20.353051           MAT0025                        CÁLCULO 1
# 4   12.522332           CIC0104                  SOFTWARE BASICO
# 5   11.615321           IFD0177            FISICA 2 EXPERIMENTAL
# 6   11.449031           IFD0179                         FISICA 3
# 7   10.202823           IFD0173            FISICA 1 EXPERIMENTAL
#
# texto buscado: Álgebra linear
# texto buscado preprocessado: ['algebra', 'linear']
#    Relevancia Código da Matéria                Nome da matéria
# 0   60.469157           MAT0031    INTRODUCAO A ALGEBRA LINEAR
# 1   56.783116           ENE0079  CONTROLE NO ESPAÇO DE ESTADOS
# 2   38.811657           CIC0229              CIRCUITOS LÓGICOS
# 3   27.744520           MAT0028            VARIAVEL COMPLEXA 1
# 4   24.874420           MAT0026                      CÁLCULO 2
# 5   20.985635           IFD0173          FISICA 1 EXPERIMENTAL
# 6   19.864266           IFD0171                       FISICA 1
# 7   19.555914           ENM0120                     MECANICA 1
#
# texto buscado: Equações diferenciais
# texto buscado preprocessado: ['equacoes', 'diferenciar']
#    Relevancia Código da Matéria  \
# 0   93.040729           MAT0026
# 1   39.342806           MAT0053
# 2   22.059378           ENE0078
# 3    7.370184           ENM0121
# 4    6.667694           MAT0059
# 5    5.674767           ENE0079
# 6    4.625110           IFD0177
# 7    4.558894           IFD0179
#
#                                   Nome da matéria
# 0                                       CÁLCULO 2
# 1                                CALCULO NUMERICO
# 2   LABORATÓRIO DE CONTROLE DE SISTEMAS DINÂMICOS
# 3                                      MECANICA 2
# 4                 METODOS MATEMÁTICOS DA FÍSICA 1
# 5                   CONTROLE NO ESPAÇO DE ESTADOS
# 6                           FISICA 2 EXPERIMENTAL
# 7                                        FISICA 3
#
# texto buscado: Geometria Analítica
# texto buscado preprocessado: ['geometria', 'analitica']
#    Relevancia Código da Matéria  \
# 0   87.636793           ENM0131
# 1   48.030835           ENM0127
# 2    0.000002           CIC0099
# 3    0.000001           ENE0048
# 4   -0.000001           IFD0181
# 5   -0.000001           CIC0126
# 6   -0.000002           ENM0027
# 7   -0.000003           EPR0068
#
#                                      Nome da matéria
# 0        DESENHO MECANICO ASSISTIDO POR COMPUTADOR 1
# 1                         TECNOLOGIA DE FABRICACAO 1
# 2          ORGANIZAÇÃO E ARQUITETURA DE COMPUTADORES
# 3  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
# 4                             FISICA 3 EXPERIMENTAL
# 5                        PROCESSAMENTO EM TEMPO REAL
# 6                    TECNOLOGIAS DE COMANDO NUMERICO
# 7                             ORGANIZAÇÃO INDUSTRIAL
#
# texto buscado: Séries
# texto buscado preprocessado: ['serie']
#    Relevancia Código da Matéria                       Nome da matéria
# 0   76.564622           MAT0059       METODOS MATEMÁTICOS DA FÍSICA 1
# 1   63.985479           MAT0026                             CÁLCULO 2
# 2   43.135533           MAT0028                   VARIAVEL COMPLEXA 1
# 3   27.754259           ENE0038  LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4   25.122958           ENE0037                 CIRCUITOS ELÉTRICOS 2
# 5   13.211061           IFD0181                FISICA 3 EXPERIMENTAL
# 6    9.392942           ENE0047   CONVERSÃO ELETROMECÂNICA DE ENERGIA
# 7    7.837956           ENE0042                 CIRCUITOS ELÉTRICOS 1
#
# texto buscado: Medidas físicas
# texto buscado preprocessado: ['medir', 'fisicas']
#    Relevancia Código da Matéria              Nome da matéria
# 0   69.178534           IFD0171                     FISICA 1
# 1   33.705562           IFD0177        FISICA 2 EXPERIMENTAL
# 2   31.818381           EST0023  PROBABILIDADE E ESTATÍSTICA
# 3   31.427097           IQD0125        QUIMICA GERAL TEORICA
# 4   29.606745           IFD0173        FISICA 1 EXPERIMENTAL
# 5   23.289609           IFD0181       FISICA 3 EXPERIMENTAL
# 6   11.232437           IQD0126   QUIMICA GERAL EXPERIMENTAL
# 7   11.183271           ENM0127   TECNOLOGIA DE FABRICACAO 1
#
# texto buscado: Mecânica
# texto buscado preprocessado: ['mecanica']
#    Relevancia Código da Matéria                              Nome da matéria
# 0   64.394391           ENM0120                                   MECANICA 1
# 1   61.125660           ENM0116                   TECNOLOGIA DE FABRICACAO 2
# 2   45.973352           IFD0171                                     FISICA 1
# 3   39.159802           ENM0121                                   MECANICA 2
# 4   22.277185           ENM0128                  TRANSPORTE DE CALOR E MASSA
# 5   21.355590           IFD0175                                     FISICA 2
# 6   17.262617           ENM0164                     MECANICA DOS MATERIAIS 1
# 7   14.877081           ENM0131  DESENHO MECANICO ASSISTIDO POR COMPUTADOR 1
#
# texto buscado: Eletromagnetismo
# texto buscado preprocessado: ['eletromagnetismo']
#    Relevancia Código da Matéria  \
# 0   92.104441           IFD0181
# 1    0.000001           ENE0048
# 2    0.000001           ENE0220
# 3   -0.000001           ENE0042
# 4   -0.000001           MAT0025
# 5   -0.000001           MAT0053
# 6   -0.000001           ENM0121
# 7   -0.000002           IFD0171
#
#                                      Nome da matéria
# 0                             FISICA 3 EXPERIMENTAL
# 1  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
# 2                         INSTRUMENTACAO DE CONTROLE
# 3                              CIRCUITOS ELÉTRICOS 1
# 4                                          CÁLCULO 1
# 5                                   CALCULO NUMERICO
# 6                                         MECANICA 2
# 7                                           FISICA 1
#
# texto buscado: Gravitação
# texto buscado preprocessado: ['gravitacao']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   84.316748           IFD0175                         FISICA 2
# 1    0.000001           ENM0121                       MECANICA 2
# 2   -0.000001           IFD0171                         FISICA 1
# 3   -0.000001           ENM0120                       MECANICA 1
# 4   -0.000001           MAT0059  METODOS MATEMÁTICOS DA FÍSICA 1
# 5   -0.000001           ENE0037            CIRCUITOS ELÉTRICOS 2
# 6   -0.000001           IFD0177            FISICA 2 EXPERIMENTAL
# 7   -0.000002           ENE0042            CIRCUITOS ELÉTRICOS 1
#
# texto buscado: Termodinâmica
# texto buscado preprocessado: ['termodinamica']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   80.631173           IFD0175                         FISICA 2
# 1   63.083094           ENM0128      TRANSPORTE DE CALOR E MASSA
# 2   26.285073           IQD0125            QUIMICA GERAL TEORICA
# 3    0.000001           ENM0121                       MECANICA 2
# 4    0.000001           ENM0164         MECANICA DOS MATERIAIS 1
# 5   -0.000001           MAT0059  METODOS MATEMÁTICOS DA FÍSICA 1
# 6   -0.000001           ENM0120                       MECANICA 1
# 7   -0.000001           IFD0173            FISICA 1 EXPERIMENTAL
#
# texto buscado: Ótica
# texto buscado preprocessado: ['otica']
# O texto procurado não há similaridade com nenhuma das demais
#
# texto buscado: Relatividade e física quântica
# texto buscado preprocessado: ['relatividade', 'fisica', 'quantica']
#    Relevancia Código da Matéria                  Nome da matéria
# 0   63.036680           IFD0171                         FISICA 1
# 1   44.404230           IQD0125            QUIMICA GERAL TEORICA
# 2   34.071615           IFD0177            FISICA 2 EXPERIMENTAL
# 3   32.745761           MAT0059  METODOS MATEMÁTICOS DA FÍSICA 1
# 4   29.928285           IFD0173            FISICA 1 EXPERIMENTAL
# 5   19.840111           ENM0120                       MECANICA 1
# 6   16.791919           IFD0179                         FISICA 3
# 7   11.828686           ENE0077   CONTROLE DE SISTEMAS DINÂMICOS
#
# texto buscado: Atividades de laboratório
# texto buscado preprocessado: ['atividades', 'laboratorio']
#    Relevancia Código da Matéria  \
# 0   63.327616           ENE0048
# 1   50.894880           ENM0133
# 2   26.748544           ENM0127
# 3   24.087787           ENE0038
# 4   22.285208           ENM0128
# 5   21.211690           ENE0044
# 6    8.541884           EPR0068
# 7    7.678676           ENE0078
#
#                                      Nome da matéria
# 0  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
# 1                INTRODUCAO A ENGENHARIA MECATRONICA
# 2                         TECNOLOGIA DE FABRICACAO 1
# 3               LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 4                        TRANSPORTE DE CALOR E MASSA
# 5               LABORATÓRIO DE CIRCUITOS ELÉTRICOS 1
# 6                             ORGANIZAÇÃO INDUSTRIAL
# 7      LABORATÓRIO DE CONTROLE DE SISTEMAS DINÂMICOS
#
# texto buscado: Estrutura atômica
# texto buscado preprocessado: ['estruturar', 'atomica']
#    Relevancia Código da Matéria                           Nome da matéria
# 0   68.718982           IQD0125                     QUIMICA GERAL TEORICA
# 1   42.907542           CIC0004  ALGORITMOS E PROGRAMAÇÃO DE COMPUTADORES
# 2   32.621995           CIC0090                       ESTRUTURAS DE DADOS
# 3   26.214397           ENM0120                                MECANICA 1
# 4   24.564953           ENM0133       INTRODUCAO A ENGENHARIA MECATRONICA
# 5   22.732729           CIC0229                         CIRCUITOS LÓGICOS
# 6   19.999328           ENM0126        INTRODUÇÃO À CIÊNCIA DOS MATERIAIS
# 7   16.688398           ENE0220                INSTRUMENTACAO DE CONTROLE
