# %% [markdown]
# Importando as matérias do curso de Mecatrônica, processando-os e adicionando uma coluna de "Documentos" no Dataframe das Matérias:
#
# Esse dataframe será salvo no arquivo: "documents_df.txt" no formato binário do Pickle.

# %%
import numpy as np
import pandas as pd
import pickle
import gensim
import spacy

from nltk.corpus import stopwords

nlp = spacy.load('pt_core_news_lg')

# * adding custom texts that dont represent real words
noises_list = ["i", "ii", "iii", "iv", "v", "vi", "vii", "viii", "ix", "x", "xi"]

stopWords_list = stopwords.words("portuguese")

# * adding custom words to StopWords list
stopWords_list += [
    'referente',
    'seguinte',
    'etc',
    'ª',
    'tal',
    'um', 
    'dois',
    'tres',
    'vs',
    'aula',
    'tal',
]

# * preprocessing stopwords to correct format
stopWords_list = gensim.utils.simple_preprocess(" ".join(stopWords_list), deacc=True, min_len=1, max_len=40)

# * manual intervention, changing final lemmas
intervention_dict = {
    "campar": "campo",
    "seriar":"serie",
    "eletromagnetico":"eletromagnetismo",
}

def preprocess(text):
    # * importing stopwords from nltk and spacy pipeline
    global nlp
    global stopWords_list
    global noises_list
    global intervention_dict

    # * preprocessing text with gensim.simple_preprocess, eliminating noises: lowercase, tokenized, no symbols, no numbers, no accents marks(normatize)
    text_list = gensim.utils.simple_preprocess(text, deacc=True, min_len=1, max_len=40)

    # * recombining tokens to a string type object and removing remaining noises
    text_str = " ".join([word for word in text_list if word not in noises_list])

    # * preprocessing with spacy, retokenizing -> tagging parts of speech (PoS) -> parsing (assigning dependencies between words) -> lemmatizing
    text_doc = nlp(text_str)

    # * re-tokenization, removing stopwords and lemmatizing
    lemmatized_text_list = [token.lemma_ for token in text_doc if token.text not in stopWords_list]

    # * manual intervention conversion of lemmas
    output = []
    for token in lemmatized_text_list:
        if token in intervention_dict:
            output.append(intervention_dict[token])
        else:
            output.append(token)
            
    return output

subjects_df = pd.read_json("MechatronicsEngeneeringSubjects.json")

documents_list = []

for i, row in subjects_df.iterrows():

    # * reading values of each subject (row)
    subject_id = row["codigo"]
    name = row["nome"]
    syllabus = row["ementa"]
    content = row["conteudo"]

    # * combining them to create the subject document
    text = name + ' ' + syllabus + ' ' + content
    
    # * preprocessing
    preProcessedText = preprocess(text)
    documents_list.append(preProcessedText)

documents_series = pd.Series(documents_list, name="documento")

documents_df = pd.concat([subjects_df, documents_series], axis=1)

with open('documents_df.txt', 'wb') as f:
    pickle.dump(documents_df, f)

# * crea topics
crea_df = pd.read_excel("Matriz_do_Conhecimento.xls", skiprows=4).iloc[:, :9].fillna(method="ffill")
crea_df = crea_df.replace({"TÓPICOS": np.NaN, "Nº DE ORDEM DOS TÓPICOS": np.NaN})

with open('crea_df_pickle.txt', 'wb') as f:
    pickle.dump(crea_df, f)

documents_df
# Out:
# D:\ANACONDA\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
#      codigo                                               nome  \
# 0   CIC0004           ALGORITMOS E PROGRAMAÇÃO DE COMPUTADORES
# 1   IFD0171                                           FISICA 1
# 2   IFD0173                              FISICA 1 EXPERIMENTAL
# 3   MAT0025                                          CÁLCULO 1
# 4   ENM0133                INTRODUCAO A ENGENHARIA MECATRONICA
# 5   IQD0125                              QUIMICA GERAL TEORICA
# 6   IQD0126                         QUIMICA GERAL EXPERIMENTAL
# 7   ENM0131        DESENHO MECANICO ASSISTIDO POR COMPUTADOR 1
# 8   EST0023                        PROBABILIDADE E ESTATÍSTICA
# 9   IFD0175                                           FISICA 2
# 10  IFD0177                              FISICA 2 EXPERIMENTAL
# 11  MAT0026                                          CÁLCULO 2
# 12  MAT0031                        INTRODUCAO A ALGEBRA LINEAR
# 13  CIC0090                                ESTRUTURAS DE DADOS
# 14  ENM0120                                         MECANICA 1
# 15  IFD0179                                           FISICA 3
# 16  IFD0181                             FISICA 3 EXPERIMENTAL
# 17  MAT0027                                          CÁLCULO 3
# 18  CIC0229                                  CIRCUITOS LÓGICOS
# 19  CIC0231                   LABORATÓRIO DE CIRCUITOS LÓGICOS
# 20  ENM0121                                         MECANICA 2
# 21  ENM0164                           MECANICA DOS MATERIAIS 1
# 22  MAT0028                                VARIAVEL COMPLEXA 1
# 23  ENE0042                              CIRCUITOS ELÉTRICOS 1
# 24  ENE0044               LABORATÓRIO DE CIRCUITOS ELÉTRICOS 1
# 25  MAT0059                    METODOS MATEMÁTICOS DA FÍSICA 1
# 26  ENE0047                CONVERSÃO ELETROMECÂNICA DE ENERGIA
# 27  ENE0048  LABORATÓRIO DE CONVERSÃO ELETROMECÂNICA DE ENE...
# 28  ENM0126                 INTRODUÇÃO À CIÊNCIA DOS MATERIAIS
# 29  ENM0127                         TECNOLOGIA DE FABRICACAO 1
# 30  ENM0128                        TRANSPORTE DE CALOR E MASSA
# 31  ENE0037                              CIRCUITOS ELÉTRICOS 2
# 32  ENE0038               LABORATÓRIO DE CIRCUITOS ELÉTRICOS 2
# 33  MAT0053                                   CALCULO NUMERICO
# 34  CIC0099          ORGANIZAÇÃO E ARQUITETURA DE COMPUTADORES
# 35  ENM0027                    TECNOLOGIAS DE COMANDO NUMERICO
# 36  ENM0118                                SISTEMAS DE MEDIÇÃO
# 37  ENE0045                                         ELETRÔNICA
# 38  ENE0046                          LABORATÓRIO DE ELETRÔNICA
# 39  ENE0077                     CONTROLE DE SISTEMAS DINÂMICOS
# 40  ENM0116                         TECNOLOGIA DE FABRICACAO 2
# 41  CIC0103                               TRANSMISSÃO DE DADOS
# 42  CIC0104                                    SOFTWARE BASICO
# 43  ENM0084                 SISTEMAS HIDRAULICOS E PNEUMATICOS
# 44  ENM0134                  SISTEMAS INTEGRADOS DE MANUFATURA
# 45  ENE0078      LABORATÓRIO DE CONTROLE DE SISTEMAS DINÂMICOS
# 46  ENE0079                      CONTROLE NO ESPAÇO DE ESTADOS
# 47  CIC0126                        PROCESSAMENTO EM TEMPO REAL
# 48  ECL0014                               CIENCIAS DO AMBIENTE
# 49  ENE0167                                   CONTROLE DIGITAL
# 50  ENE0220                         INSTRUMENTACAO DE CONTROLE
# 51  EPR0068                             ORGANIZAÇÃO INDUSTRIAL
#
#                                                ementa  \
# 0   Princípios fundamentais de construção de progr...
# 1   Módulos 1: Unidades e grandezas físicas 2: Vet...
# 2   MEDIDAS E ERROS. ANALISE GRAFICA. ATRITO. COLI...
# 3   Funções de uma variável real, limite e continu...
# 4   A Universidade de Brasília. Engenharia, Contro...
# 5   Abordagem conceitual dos princípios fundamenta...
# 6   CARACTERIZACAO DA NATUREZA E DO PAPEL DAS INVE...
# 7   Objetivos da Disciplina: A disciplina objetiva...
# 8   Análise Descritiva, Cálculo de Probabilidades,...
# 9   Módulos 1: Equilíbrio e elasticidade 2: Gravit...
# 10  GIROSCOPIO. MOVIMENTO PERIODICO. HIDROSTATICA....
# 11  Sequências e séries numéricas séries de potênc...
# 12  Sistemas lineares e matrizes Espaços vetoriais...
# 13  Gerenciamento dinâmico da memória. Listas. Pil...
# 14  INTRODUCAO CONCEITOS BASICOS EQUILIBRIO DE COR...
# 15  LEI DE COULOMB. O CAMPO ELETRICO - LEI DE GAUS...
# 16  FUNDAMENTOS TEÓRICOS USO DE MEDIDORES ELÉTRICO...
# 17  Vetores no plano e no espaço funções de várias...
# 18  Álgebra Booleana. Estruturas de Portas Lógicas...
# 19  Linguagem de Descrição de Hardware. Portas Lóg...
# 20  INTRODUÇÃO CONCEITOS BÁSICOS MÉTODOS DE ENERGI...
# 21  INTRODUCAO A ELASTICIDADE: DEFORMACOES, FORCAS...
# 22  Números complexos Funções de uma variável comp...
# 23  Conceitos básicos. Circuitos resistivos. Técni...
# 24  Experimentos de laboratório referente aos segu...
# 25  ALGUMAS EQUACOES DA FISICA MATEMATICA. SERIES ...
# 26  Introdução aos princípios de máquinas transfor...
# 27  Ensaios com carga e com transformadores monofá...
# 28  Programa da disciplina (aulas teóricas).1. Int...
# 29  PROCESSOS DE FABRICAÇÃO COM REMOÇÃO DE MATERIA...
# 30  FUNDAMENTOS DE FENÔMENOS DE TRANSPORTE.PROPRIE...
# 31  Redes magneticamente acopladas. Desempenho das...
# 32  Experimentos de laboratório referente aos segu...
# 33  ZEROS DE FUNCOES. ZEROS DE POLINOMIOS SISTEMAS...
# 34  Desempenho de Processadores. Arquitetura do Co...
# 35  ## => CONCEITUAÇÃO DE UM SISTEMA DE COMANDO NU...
# 36  Expressão de termos metrológicos segundo o Voc...
# 37  Introdução a eletrônica. Amplificadores operac...
# 38  Realização de um conjunto de experiências que ...
# 39  Modelagem de sistemas dinâmicos. Diagrama de b...
# 40  Esta disciplina enfoca aspectos de classificaç...
# 41  \tFUNDAMENTOS DA COMUNICACAO TRANSMISSAO DE DA...
# 42  Linguagem de montagem montadores, ligadores e ...
# 43  Os PRINCIPIOS DE FUNCIONAMENTO DE COMPONENTES ...
# 44  ### A VISÃO INTEGRADA DA AUTOMAÇÃO INDUSTRIAL....
# 45  \tFerramentas computacionais. Modelagem de sis...
# 46  \tRevisão de álgebra linear. Descrição matemát...
# 47  Introdução. Características, abstração e model...
# 48  A BIOSFERA E SEU EQUILÍBRIO. EFEITOS DA TECNOL...
# 49  SISTEMAS DISCRETOS. REPRESENTACAO DA DINAMICA ...
# 50  ### ESTRUTURA GERAL DE UM SISTEMA DE MEDIÇÃO E...
# 51  Maturidade e valor em sistemas de produção. Es...
#
#                                              conteudo  \
# 0
# 1   I-MEDICAO: GRANDEZAS, PADROES E UNIDADES FISIC...
# 2   I-CLASSIFICACAO DOS ERROS. CALCULO DE ERRO EXP...
# 3   1. Funções: conceito de função exemplo de funç...
# 4
# 5   1.Estrutura Atômica e a Lei Periódica: O Model...
# 6   1) Noções Básicas sobre Segurança no Trabalho ...
# 7   - Normas de desenho Técnico- Introdução ao CAD...
# 8   UNIDADE I - Análise Descritiva de Dados - Popu...
# 9   1-CONTEUDO TEORICO 1-DINAMICA DA ROTACAO 1.1- ...
# 10  I-DINAMICA DE ROTACAO. ESTUDO DO GIROSCOPIO. T...
# 11  1. Sequências Séries numéricas2. Séries de pot...
# 12  1. Sistemas lineares e matrizes: operações ele...
# 13  Gerenciamento dinâmico da memória.Listas. Pilh...
# 14  1.0 - INTRODUÇÃO 1.1 - Domínio da mecânica 1.2...
# 15  I-LEI DE COULOMB. CONSERVACAO DA CARGA. CAMPO ...
# 16  EXPERIENCIA 1 - USO DE MEDIDORES ELÉTRICOS E F...
# 17  1. Vetores no plano e no espaço: conceito e pr...
# 18  1. Introdução 1.1. Grandezas digitais e analóg...
# 19  1. Introdução 1.1. Instrumental básico 1.2. Pr...
# 20  1.0 - INTRODUÇÃO 1.1 - Modelagem dinâmica de s...
# 21  1.0 - INTRODUCAO A ELASTICIDADE LINEAR 1.1 - D...
# 22  1. Números complexos: representação geométrica...
# 23  1 CONCEITOS BÁSICOS 1.1 Sistemas de Unidades 1...
# 24  Experimentos de laboratório referente aos segu...
# 25  1. EQUACAO DA ONDA, EQUACAO DO CALOR E EQUACAO...
# 26  1 ? Introdução aos princípios de máquinas ? Mo...
# 27  Laboratório 1: Correção de fator de potência.L...
# 28
# 29  1.0 - NOÇÕES FUNDAMENTAIS DE TOLERÂNCIAS E AJU...
# 30  I - FUNDAMENTOS# Introdução# Fundamentos de Fe...
# 31  1 REDES MAGNETICAMENTE ACOPLADAS 1.1 Indutânci...
# 32  Experimentos de laboratório referente aos segu...
# 33  ZEROS DE FUNCOES REAIS: ISOLAMENTO DE RAIZES, ...
# 34  Introdução- Motivação- Histórico- Arquiteturas...
# 35  1.0 - ## => INTRODUÇÃO:1.1 - ## => Histórico1....
# 36   Introdução aos sistemas de medição Descrição ...
# 37  Introdução a eletrônica- Relevância de eletrôn...
# 38  Ao longo do curso deverá ser realizado um conj...
# 39  Modelagem de sistemas dinâmicos- Modelagem de ...
# 40
# 41  01. FUNDAMENTOS DA COMUNICACAO 1.1. CONCEITOS ...
# 42  1. PROGRAMACAO EM LINGUAGEM DE MAQUINA. 1.1 IN...
# 43  1. Introdução Apresentação do plano de Discipl...
# 44  1.0 - Modelo de Referência para Manufatura Int...
# 45  Ferramentas computacionais:- Simulação de sist...
# 46  Revisão de álgebra linear- Espaços vetoriais- ...
# 47  1. Introdução Sistemas de Tempo Real Caracterí...
# 48  Cronograma Aula 1 - Introdução ao curso Aula 2...
# 49  SISTEMAS DISCRETOS. REPRESENTACAO DA DINAMICA ...
# 50  1.0 - ESTRUTURA GERAL DE UM SISTEMA DE MEDIÇÃO...
# 51  a. MATURIDADE E VALOR EM SISTEMAS DE PRODUÇÃO:...
#
#                                             documento
# 0   [algoritmo, programacao, computador, principio...
# 1   [fisica, modulos, unidade, grandeza, fisicas, ...
# 2   [fisica, experimental, medir, erro, analisar, ...
# 3   [calcular, funcoes, variavel, real, limitar, c...
# 4   [introducao, engenhar, mecatronica, universida...
# 5   [quimica, geral, teorica, abordagem, conceitua...
# 6   [quimica, geral, experimental, caracterizacao,...
# 7   [desenhar, mecanico, assistir, computador, obj...
# 8   [probabilidade, estatistica, analisar, descrit...
# 9   [fisica, modulos, equilibrio, elasticidade, gr...
# 10  [fisica, experimental, giroscopio, movimentar,...
# 11  [calcular, sequencias, serie, numericas, serie...
# 12  [introducao, algebra, linear, sistema, linear,...
# 13  [estruturar, dar, gerenciamento, dinamico, mem...
# 14  [mecanica, introducao, conceito, basicos, equi...
# 15  [fisica, lei, coulomb, campo, eletrico, lei, g...
# 16  [fisica, experimental, fundamento, teoricos, u...
# 17  [calcular, vetores, planar, espaco, funcoes, v...
# 18  [circuito, logicos, algebra, booleana, estrutu...
# 19  [laboratorio, circuito, logicos, linguagem, de...
# 20  [mecanica, introducao, conceito, basicos, meto...
# 21  [mecanica, material, introducao, elasticidade,...
# 22  [variavel, complexo, numeros, complexo, funcoe...
# 23  [circuito, eletricos, conceito, basicos, circu...
# 24  [laboratorio, circuito, eletricos, experimento...
# 25  [metodos, matematicos, fisica, algum, equacoes...
# 26  [conversao, eletromecanica, energia, introduca...
# 27  [laboratorio, conversao, eletromecanica, energ...
# 28  [introducao, ciencia, material, programar, dis...
# 29  [tecnologia, fabricacao, processo, fabricacao,...
# 30  [transportar, calor, massa, fundamento, fenome...
# 31  [circuito, eletricos, rede, magneticamente, ac...
# 32  [laboratorio, circuito, eletricos, experimento...
# 33  [calcular, numerico, zero, funcoes, zero, poli...
# 34  [organizacao, arquitetura, computador, desempe...
# 35  [tecnologia, comandar, numerico, conceituacao,...
# 36  [sistema, medicao, expressao, termo, metrologi...
# 37  [eletronica, introducao, eletronica, amplifica...
# 38  [laboratorio, eletronica, realizacao, conjunta...
# 39  [controlo, sistema, dinamicos, modelagem, sist...
# 40  [tecnologia, fabricacao, disciplinar, enfoca, ...
# 41  [transmissao, dar, fundamento, comunicacao, tr...
# 42  [software, basico, linguagem, montagem, montad...
# 43  [sistema, hidraulicos, pneumaticos, principios...
# 44  [sistema, integrar, manufatura, visao, integra...
# 45  [laboratorio, controlo, sistema, dinamicos, fe...
# 46  [controlo, espaco, estar, revisao, algebra, li...
# 47  [processamento, tempo, real, introducao, carac...
# 48  [ciencias, ambientar, biosfera, equilibrio, ef...
# 49  [controlo, digital, sistema, discreto, represe...
# 50  [instrumentacao, controlo, estruturar, geral, ...
# 51  [organizacao, industrial, maturidade, valor, s...
